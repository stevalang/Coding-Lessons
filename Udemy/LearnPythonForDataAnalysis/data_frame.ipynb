# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser

# %%
websites = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'

# %%
webbrowser.open(websites)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_frame.Team
# Out:
# 0       Green Bay Packers
# 1          Dallas Cowboys
# 2        Baltimore Ravens
# 3           Chicago Bears
# 4    New England Patriots
# Name: Team, dtype: object

# %%
nfl_frame['First NFL season']
# Out:
# 0    1921
# 1    1960
# 2    1996
# 3    1920
# 4    1960
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL season', 'Division', 'Stadium'])
# Out:
#                    Team  First NFL season   Division  Stadium
# 0     Green Bay Packers              1921  NFC North      NaN
# 1        Dallas Cowboys              1960   NFC East      NaN
# 2      Baltimore Ravens              1996  AFC North      NaN
# 3         Chicago Bears              1920  NFC North      NaN
# 4  New England Patriots              1960   AFC East      NaN

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame.tail(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division         Stadium
# 0              1921  NFC North  Levi's Stadium
# 1              1960   NFC East  Levi's Stadium
# 2              1996  AFC North  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division  Stadium
# 0              1921  NFC North        0
# 1              1960   NFC East        1
# 2              1996  AFC North        2
# 3              1920  NFC North        3
# 4              1960   AFC East        4

# %%
stadiums = Series(['Levi\'s Stadium', 'AT&T Stadium'], index = [4, 0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division         Stadium
# 0              1921  NFC North    AT&T Stadium
# 1              1960   NFC East             NaN
# 2              1996  AFC North             NaN
# 3              1920  NFC North             NaN
# 4              1960   AFC East  Levi's Stadium

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769   577    38  0.569
# 1     2        Dallas Cowboys    930  526   398     6  0.569
# 2     3      Baltimore Ravens    400  225   174     1  0.564
# 3     4         Chicago Bears  1,418  777   599    42  0.563
# 4     5  New England Patriots    932  519   404     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
data = {'City':['SF', 'LA', 'NYC'], 'Population':[8370000,3877700, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF     8370000
# 1   LA     3877700
# 2  NYC     8400000
