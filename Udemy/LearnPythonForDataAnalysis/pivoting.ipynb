# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
#import pandas testing utility
import pandas.util.testing as tm; tm.N = 3

#Create a unpivoted function
def unpivot(frame):
    N, K = frame.shape
    
    data = {'value' : frame.values.ravel('F'), 
            'variable' : np.asarray(frame.columns).repeat(N),
            'date' : np.tile(np.asarray(frame.index), K)}
    
    # Return the DataFrame
    return DataFrame(data, columns=['date', 'variable', 'value'])

#Set the DataFrame we'll be using
dframe = unpivot(tm.makeTimeDataFrame())

# %%
dframe
# Out:
#           date variable     value
# 0   2000-01-03        A -0.815254
# 1   2000-01-04        A  0.294221
# 2   2000-01-05        A  0.862944
# 3   2000-01-06        A -0.684843
# 4   2000-01-07        A  0.340942
# ..         ...      ...       ...
# 115 2000-02-07        D -0.540728
# 116 2000-02-08        D  1.877339
# 117 2000-02-09        D  0.251436
# 118 2000-02-10        D  0.621612
# 119 2000-02-11        D  0.837536
#
# [120 rows x 3 columns]

# %%
dframe_piv = dframe.pivot('date', 'variable', 'value')

# %%
dframe_piv
# Out:
# variable           A         B         C         D
# date
# 2000-01-03 -0.815254 -1.396795 -1.030557 -2.002420
# 2000-01-04  0.294221  0.168953 -0.963332  0.352050
# 2000-01-05  0.862944  0.976009 -0.066887  0.195228
# 2000-01-06 -0.684843  0.512875 -0.918371  1.010780
# 2000-01-07  0.340942 -0.270059  0.166444 -0.071808
# 2000-01-10 -1.452439 -0.244235 -0.109123  0.492398
# 2000-01-11 -1.175078 -0.944569  0.154026  0.818362
# 2000-01-12 -0.280332  0.930376  0.923603  1.749207
# 2000-01-13  1.175523 -1.963079  1.240412 -1.387694
# 2000-01-14 -0.227325  1.340814  0.668423  2.261290
# 2000-01-17  0.800784 -0.170033  1.422542  1.108706
# 2000-01-18 -0.846552 -0.324566 -0.374841  0.020485
# 2000-01-19  0.718649  0.579273 -1.100959  0.698962
# 2000-01-20 -0.311603 -1.402443  0.622643  0.103436
# 2000-01-21 -0.611295  0.752295  0.321399 -0.857338
# 2000-01-24 -0.972128 -1.436274  0.031537 -0.283015
# 2000-01-25 -1.082214  0.244916  0.116414  1.420913
# 2000-01-26  0.221438  0.732574  2.218299 -0.606877
# 2000-01-27 -1.433453 -0.057691 -0.166360 -1.436445
# 2000-01-28 -0.427132 -1.166220  0.774063  0.372913
# 2000-01-31 -0.288054  0.516166  0.658553  0.412451
# 2000-02-01 -1.228549 -1.160140 -0.600121 -0.577993
# 2000-02-02 -0.703735  2.946695  0.500352 -0.702911
# 2000-02-03  0.213682  0.027297 -1.297229  0.802874
# 2000-02-04  0.633357 -0.803185 -0.356919  1.276348
# 2000-02-07 -1.380967 -2.047665  0.802479 -0.540728
# 2000-02-08 -0.397469 -1.686740  1.066626  1.877339
# 2000-02-09  0.083295  1.335886 -2.486269  0.251436
# 2000-02-10  0.612325  1.348418 -0.546231  0.621612
# 2000-02-11  0.332062 -1.170147 -0.569469  0.837536
